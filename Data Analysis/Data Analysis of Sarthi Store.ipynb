# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('FinalData.csv')

# %%
data.shape
# Out:
# (2074, 6)

# %%
data.head()
# Out:
#           Item  Quantity           Category Customer       CustomerType  Price
# 0      Perfume         1  Men's Accessories     Male   Teen = 13-19 yrs    100
# 1       Spoons         1            Kitchen   Female  Adult = 20-39 yrs     80
# 2          Mop         1          Household   Female  Adult = 20-39 yrs    120
# 3        Broom         1          Household   Female  Adult = 20-39 yrs    100
# 4  Kitchen set         1            Kitchen   Female  Adult = 20-39 yrs    200

# %%
data.isnull().sum()
# Out:
# Item            0
# Quantity        0
# Category        0
# Customer        0
# CustomerType    0
# Price           0
# dtype: int64

# %%
data['Item'].value_counts()
# Out:
# Perfume           361
# Coffee Cup        350
# Broom             184
# Lower             184
# Mop               169
# Cream             166
# Spoons            161
# Wallet            141
# Hair Gel          117
# Cup Set            70
# Shirt              69
# Cup set            49
# Cup                 9
# Tshirt              7
# Belt                4
# Brush Set           4
#  Cup                4
# Watch               4
# Fairness Cream      3
# Kitchen set         3
# Googles             3
# Plates              1
# Mug                 1
# Bucket              1
# Shampoo             1
# Toothpaste          1
# Powder              1
# Moisturizer         1
# Door Mat            1
# Flower pot set      1
# Stool               1
# Pan                 1
# Washing brush       1
# Name: Item, dtype: int64

# %%
data['Item'] = data['Item'].replace('Cup set', 'Cup Set ')
data['Item'] = data['Item'].replace(' Cup', 'Cup')
data['Item'] = data['Item'].replace('Mug', 'Cup')

# %%
data['Item'].value_counts()
# Out:
# Perfume           361
# Coffee Cup        350
# Broom             184
# Lower             184
# Mop               169
# Cream             166
# Spoons            161
# Wallet            141
# Hair Gel          117
# Cup Set            70
# Shirt              69
# Cup Set            49
# Cup                14
# Tshirt              7
# Brush Set           4
# Belt                4
# Watch               4
# Googles             3
# Kitchen set         3
# Fairness Cream      3
# Door Mat            1
# Flower pot set      1
# Shampoo             1
# Powder              1
# Toothpaste          1
# Plates              1
# Bucket              1
# Stool               1
# Pan                 1
# Washing brush       1
# Moisturizer         1
# Name: Item, dtype: int64

# %%
len(data['Item'].value_counts())
# Out:
# 31

# %%
data['Category'].value_counts()
# Out:
# Men's Accessories    699
# Kitchen              606
# Household            414
# Clothing             191
# Cosmetic             164
# Name: Category, dtype: int64

# %%
data['Customer'].value_counts()
# Out:
# Female    1183
# Male       891
# Name: Customer, dtype: int64

# %%
data['Customer'].value_counts() / len(data['Customer']) * 100
# Out:
# Female    57.039537
# Male      42.960463
# Name: Customer, dtype: float64

# %%
data['CustomerType'].value_counts()
# Out:
# Adult = 20-39 yrs               1275
# Teen = 13-19 yrs                 789
# Middle Age Adult = 40-59 yrs      10
# Name: CustomerType, dtype: int64

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Item'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Item'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Category'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Customer'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Customer'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['CustomerType'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='CustomerType'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Customer'], hue=data['Category'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Customer'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Item'], hue=data['Customer'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Item'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Category'], hue=data['CustomerType'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %%
data[data['CustomerType']=='Teen = 13-19 yrs'][['Category']].value_counts()
# Out:
# Category
# Men's Accessories    627
# Cosmetic             161
# Household              1
# dtype: int64

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Category'], hue=data['Customer'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Category'>

# %%
from matplotlib.pyplot import figure
figure(figsize=(21,12), dpi=80)
sns.barplot(data['Price'], data['Item'], hue=data['Category'])
# Out:
# C:\Users\HP\new_anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Price', ylabel='Item'>

# %% [markdown]
# ### Observations:
# * We have total 2074 number records and this contains 120 days. So, average item sale per day will be: **`17-18`**.
# * Average Sales is in range of: **`1700-2200 INR`**.
# * They have 31 Unique Items in their shop according to data.
# * Female buyer ratio is : **`60%`** approx..
# * Males are spend more money as comapare to females.
# * Most of the buyers are in age range of: **`18-40 years`**.
# * Males are buy Household products and Females are more interested in Clothing Category.
